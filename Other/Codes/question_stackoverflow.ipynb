# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
k = 0.02
m = 0.002
e = k-m*n_rows
yo = 1#0.91 #+ e
# labels
#fig.text(0.513, 0.06, 'Time UTC', ha='center', va='center', fontsize=14)
fig.text(0.09, 0.5, 'S4', ha='center', va='center', rotation='vertical', fontsize=14, color='b')
fig.text(0.94, 0.5, 'Elevation Angle', ha='center', va='center', rotation=-90, fontsize=14, color='g')
# title
#fig.text(0, -0.5, 'S4', ha='center', va='center', fontsize=17, transform=ax.transAxes)
#fig.text(0.32, yo, 'Jicamarca', ha='center', va='center', fontsize=17, color='r', transform=ax.transAxes)
#fig.text(0.12, yo, '2020/07/16', ha='left', va='center', fontsize=17, transform=ax.transAxes)
#fig.text(0.9, yo, 'Scintillation index', ha='right', va='center', fontsize=17, transform=ax.transAxes)
plt.savefig("question1.png")

# %%
n_rows = 2
n_cols = 2
fig, axs = plt.subplots(n_rows, n_cols, figsize=(7*n_cols,1*n_rows), sharex="col", sharey="row",
                        gridspec_kw={'hspace': 0, 'wspace': 0})
i = 0
for ax in axs.T.reshape(-1):
    if i == 0: # Upper left  
        print(i)
        ax.plot([1,2,3],[1,2,3])
        fig.text(0, 1, '2020/07/16', ha='left', va='bottom', fontsize=17, transform=ax.transAxes)
        fig.text(0.5, 1, 'Jicamarca', ha='left', va='bottom', fontsize=17, transform=ax.transAxes)
    
    if i == n_rows-1: # Lower left 
        print(i)
        ax.plot([2,3,4],[2,3,4])
    
    if i == n_rows: # Upper right
        print(i)
        ax.plot([3,4,5],[3,4,5])
        #fig.text(0, 1.3, 'S4', ha='center', va='center', fontsize=17, transform=ax.transAxes)
        fig.text(0, 1, 'S4', ha='center', va='bottom', fontsize=17, transform=ax.transAxes)
        fig.text(0.4, 1, '1176.45MHz', ha='center', va='bottom', fontsize=17, transform=ax.transAxes)
        fig.text(1, 1, 'L5|SBAS', ha='right', va='bottom', fontsize=17, transform=ax.transAxes)

    if i == n_rows*n_cols-1: # Lower right
        print(i)
        ax.plot([4,5,6],[4,5,6])
        fig.text(0, -0.6, 'Time UTC', ha='center', va='center', fontsize=14, transform=ax.transAxes)
    
    if i == int(n_rows/2): # y axis label on the left
        k = (n_rows%2)*0.5
        fig.text(-0.1, 1-k, 'S4', ha='center', va='center', rotation='vertical', fontsize=14, color='b', transform=ax.transAxes)
    
    if i == int(n_rows*n_cols-n_rows/2): # y axis label on the right 
        k = (n_rows%2)*0.5
        fig.text(1.1, 1-k, 'Elevation', ha='center', va='center', rotation=-90, fontsize=14, color='g', transform=ax.transAxes)
        
    i += 1
# Out:
# 0
# 1
# 2
# 3

# %%
n_rows = 24
n_cols = 2
fig, axs = plt.subplots(n_rows, n_cols, figsize=(7*n_cols,1*n_rows), sharex="col", sharey="row",
                        gridspec_kw={'hspace': 0, 'wspace': 0})

#labels
fig.text(0.513, 0.08, 'Time UTC', ha='center', va='center', fontsize=14)
fig.text(0.09, 0.5, 'S4', ha='center', va='center', rotation='vertical', fontsize=14, color='b')
fig.text(0.94, 0.5, 'Elevation Angle', ha='center', va='center', rotation=-90, fontsize=14, color='g')
# title
fig.text(0.513, 0.895, 'S4', ha='center', va='bottom', fontsize=17, weight='roman')
fig.text(0.32, 0.895, 'Jicamarca', ha='center', va='center', fontsize=17, weight='roman', color='r')
fig.text(0.12, 0.895, '2020/07/16', ha='left', va='center', fontsize=17, weight='roman')
fig.text(0.9, 0.895, 'Scintillation index', ha='right', va='center', fontsize=17, weight='roman')
plt.show()

# %%
1397.148/60
# Out:
# 23.2858

# %%
11.6/12.2
# Out:
# 0.9508196721311476

# %%
import matplotlib.pyplot as plt

# Build a rectangle in axes coords
left, width = .25, .5
bottom, height = .25, .5
right = left + width
top = bottom + height
ax = plt.gca()
print(ax)
p = plt.Rectangle((left, bottom), width, height, fill=False)
p.set_transform(ax.transAxes)
p.set_clip_on(False)
ax.add_patch(p)


ax.text(left, bottom, 'left top',
        horizontalalignment='left',
        verticalalignment='top')

ax.text(left, bottom, 'left bottom',
        horizontalalignment='left',
        verticalalignment='bottom',
        transform=ax.transAxes)

ax.text(right, top, 'right bottom',
        horizontalalignment='right',
        verticalalignment='bottom',
        transform=ax.transAxes)

ax.text(right, top, 'right top',
        horizontalalignment='right',
        verticalalignment='top',
        transform=ax.transAxes)

ax.text(right, bottom, 'center top',
        horizontalalignment='center',
        verticalalignment='top',
        transform=ax.transAxes)

ax.text(left, 0.5 * (bottom + top), 'right center',
        horizontalalignment='right',
        verticalalignment='center',
        rotation='vertical',
        transform=ax.transAxes)

ax.text(left, 0.5 * (bottom + top), 'left center',
        horizontalalignment='left',
        verticalalignment='center',
        rotation='vertical',
        transform=ax.transAxes)

ax.text(0.5 * (left + right), 0.5 * (bottom + top), 'middle',
        horizontalalignment='center',
        verticalalignment='center',
        transform=ax.transAxes)

ax.text(right, 0.5 * (bottom + top), 'centered',
        horizontalalignment='center',
        verticalalignment='center',
        rotation='vertical',
        transform=ax.transAxes)

ax.text(left, top, 'rotated\nwith newlines',
        horizontalalignment='center',
        verticalalignment='center',
        rotation=45,
        transform=ax.transAxes)

plt.axis('off')

plt.show()
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
from pylab import figure, text, scatter, show
import matplotlib.pyplot as plt
f = figure()
ax = f.add_subplot(111)
print(ax)
scatter([3,5,2,6,8],[500,3,80,100,5])
text(0.1, 0.9,'matplotlib', ha='center', va='center', transform=ax.transAxes)
plt.legend(['A simple line'], loc=10)
# Out:
# AxesSubplot(0.125,0.125;0.775x0.755)

# %%
line1 = Line2D(range(10), range(10), marker='o', color="goldenrod")
line2 = Line2D(range(10), range(10), marker='o',color="firebrick")
line3 = Line2D(range(10), range(10), marker='o',color="lightgreen")
line4 = Line2D(range(10), range(10), marker='o',color="dodgerblue")
plt.legend((line1,line2,line3, line4),('line1','line2', 'line3', 'line4'),numpoints=1, loc=2)
