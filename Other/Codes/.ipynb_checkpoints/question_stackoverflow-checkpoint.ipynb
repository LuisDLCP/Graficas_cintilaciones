# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
n_rows = 15
n_cols = 2
fig, axs = plt.subplots(n_rows, n_cols, figsize=(7*n_cols,1*n_rows), sharex="col", sharey="row",
                        gridspec_kw={'hspace': 0, 'wspace': 0})  
# labels
fig.text(0.513, 0.06, 'Time UTC', ha='center', va='center', fontsize=14)
fig.text(0.09, 0.5, 'S4', ha='center', va='center', rotation='vertical', fontsize=14, color='b')
fig.text(0.94, 0.5, 'Elevation Angle', ha='center', va='center', rotation=-90, fontsize=14, color='g')
# title
fig.text(0.513, 0.91, 'S4', ha='center', va='center', fontsize=17, transform=ax.transAxes)
fig.text(0.32, 0.91, 'Jicamarca', ha='center', va='center', fontsize=17, color='r', transform=ax.transAxes)
fig.text(0.12, 0.91, '2020/07/16', ha='left', va='center', fontsize=17, transform=ax.transAxes)
fig.text(0.9, 0.91, 'Scintillation index', ha='right', va='center', fontsize=17, transform=ax.transAxes)
plt.savefig("question1.png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-76c4513c5bfe> in <module>
#       8 fig.text(0.94, 0.5, 'Elevation Angle', ha='center', va='center', rotation=-90, fontsize=14, color='g')
#       9 # title
# ---> 10 fig.text(0.513, 0.91, 'S4', ha='center', va='center', fontsize=17, transform=ax.transAxes)
#      11 fig.text(0.32, 0.91, 'Jicamarca', ha='center', va='center', fontsize=17, color='r', transform=ax.transAxes)
#      12 fig.text(0.12, 0.91, '2020/07/16', ha='left', va='center', fontsize=17, transform=ax.transAxes)
#
# NameError: name 'ax' is not defined

# %%
#labels
fig.text(0.513, 0.08, 'Time UTC', ha='center', va='center', fontsize=14)
fig.text(0.09, 0.5, 'S4', ha='center', va='center', rotation='vertical', fontsize=14, color='b')
fig.text(0.94, 0.5, 'Elevation Angle', ha='center', va='center', rotation=-90, fontsize=14, color='g')
# title
fig.text(0.513, 0.895, 'S4', ha='center', va='center', fontsize=17, weight='roman')
fig.text(0.32, 0.895, 'Jicamarca', ha='center', va='center', fontsize=17, weight='roman', color='r')
fig.text(0.12, 0.895, '2020/07/16', ha='left', va='center', fontsize=17, weight='roman')
fig.text(0.9, 0.895, 'Scintillation index', ha='right', va='center', fontsize=17, weight='roman')
plt.show()

# %%
1397.148/60
# Out:
# 23.2858
